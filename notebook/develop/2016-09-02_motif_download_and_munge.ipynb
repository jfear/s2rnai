# %%
# %load ../start.py
# Load useful extensions

# Activate the autoreload extension for easy reloading of external packages
# %reload_ext autoreload
# %autoreload 1

# Set up cashdir
from ipycache import CacheMagics
CacheMagics.cachedir = '../cachedir'

# Trun on the water mark
# %reload_ext watermark
# %watermark -a "Justin M Fear" -u -d -v

# Load ipycache extension
# %reload_ext ipycache
from ipycache import CacheMagics
CacheMagics.cachedir = '../cachedir'

# Add project library to path
import sys
sys.path.insert(0, '../../lib/python')
# Out:
# Justin M Fear
# last updated: 2016-10-05
#
# CPython 3.5.2
# IPython 5.1.0

# %% [markdown]
# In the last S2 cell RNAi project meeting we reviewed Yijie's network model. One concern that I had was the addition of edges from transcription factors to genes, when a gene is highly correlated. For example:
#
# ```
# TFa -> A
#
# A and B are highly correlated...
#
# Add edge TFa ->B
# ```
#
# This is a good idea, but does not necessarily hold true. We decided the addition of motif information would be important. Then we could only add `TFa->B` when `B` has a motif from `TFa`.
#
# Lee had started generating a TF motif list/weights, but Brian wanted him to stop this and have me do it. They basic analysis plan is:
#
# 1. Download annotated TF motifs from various online sources.
# 2. Map motifs to the genome and identify motifs within some range of the TSS.
# 3. Do the same thing across Drosophila species and calculate a conservation score (see DSX motif paper).
# 4. Build a weight matrix where each row is a gene and each column is transcription factor. Valuse can either be binary or weights for if the TF motif was within the regulatory region of the gene.
#
# Lee has looked for sources of motifs and concluded that the MEME website is a good source. Here is an email from Lee updating me on this information:
#
#     Justin,
#
#     My R scripts seem to be not super-helpful.  There are just about how I defined TSS regions (+ first introns).  I assigned a motif to a gene when a motif is within the range between 1kb upstream to min(500bp downstream or first intron end).  Just briefly go over for fun.
#
#
#     You can download the weight matrices from MEME, but I attach here, too.
#
#     OnTheFly data, used very weird IDs, which are mixture of Swissprot and others.  It is very nagging to deal with it, so I actually crawled their website (which also in in the Handling_motif_data.R).  I attach the ID conversion matrix.  This will be very useful.
#
#
#     FIMO results are quite large, and I don’t think that you will use them.  But the links follow.
#     https://www.dropbox.com/s/czse5ur5md8wm1u/OnTheFly_2014_p0.0001.txt?dl=0
#     https://www.dropbox.com/s/hq812lsv6hijqet/fly_factor_survey_p0.0001.txt?dl=0
#
#     An example of my FIMO code is below
#     cd /data/leehang/motif/fly_factor_survey; fimo --qv-thresh --thresh 0.05 ./fly_factor_survey.meme ~/Annotation/Dmel.FB6_06.fa
#
#
#     Lee
#
# I think I am going to approach this cleanly so that I know exactly where and how files were downloaded.

# %%
# Imports
import os
import tarfile
from urllib.request import urlretrieve, urlopen
from tempfile import mkstemp

import pandas as pd

from Bio import motifs

# My library
import meme

# %%
# Download MEME motif database
if not os.path.exists('../../data/external/meme/motif_databases/FLY/fly_factor_survey.meme'):
    # Download file
    temp = mkstemp(suffix='tgz')
    urlretrieve(url='http://meme-suite.org/meme-software/Databases/motifs/motif_databases.12.12.tgz', filename=temp[1])
    
    # Make sure output dir is there
    if not os.path.exists('../../data/external/meme'):
        os.mkdir('../../data/external/meme')

    # Open tar
    tar = tarfile.open(temp[1])

    # Extract only the Fly data
    def fly(members):
        for tarinfo in members:
            if 'FLY' in tarinfo.name:
                yield tarinfo
    
    tar.extractall(path='../../data/external/meme', members=fly(tar))
    
    # Clean up
    tar.close()
    os.unlink(temp[1])

# %%
# %%cache -s flyfactory.pkl flyFactoryTFS
# # Verify Meme downloads
# flyFactoryTFS = meme.memeFile('../../data/external/meme/motif_databases/FLY/fly_factor_survey.meme')
# # According to the meme website the fly factor database has 656 motifs, this will error if not
# assert flyFactoryTFS .count() == 656

# %%
# %%cache -s onthefly.pkl onTheFlyTFS
# # map OnTheFly to FBgn
#
# # The OnTheFly motifs are not as stright forward because they use their own identifier. There is an added step to query their website and get the FBgn value.
# URL = 'https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-bin/protein_entry.php?protein_ID={0}'
# def map_onthefly(tf):
#     try:
#         query = '_'.join(tf.name.split('_')[:-1])
#         with urlopen(URL.format(query)) as fh:
#             return re.findall(r'FBgn\d+', fh.read().decode('utf-8'))[0]
#     except:
#         print(tf.id, tf.name)
#         pass
#
# onTheFlyTFS = meme.memeFile('../../data/external/meme/motif_databases/FLY/OnTheFly_2014_Drosophila.meme')
# # According to the meme website the fly factor database has 608 motifs, this will error if not
# assert onTheFlyTFS.count() == 608
#
# # Get a list of all the IDs
# keys = list(onTheFlyTFS.keys())
#
# for key in keys:
#     fbgn = map_onthefly(onTheFlyTFS[key][0])
#     if fbgn is not None:
#         onTheFlyTFS.replace_id(key, fbgn)
# Out:
# OTF0415
# OTF0408
# OTF0237
# OTF0160
# OTF0208
# OTF0515
# OTF0339
# OTF0279
# OTF0223
# OTF0388
# OTF0067

# %%
# Lee had also done a webscrapper, so I want to compare and verify that we got the same results
lee = pd.read_csv('../../data/lee/OnTheFly_ID_conversion.txt', sep='\t')

# %%
lee
# Out:
#          motif              summary       uniprot  \
# 0    OTF0001.1       7UP1_DROME_B1H    7UP1_DROME
# 1    OTF0002.1     A0AQF9_DROME_B1H  A0AQF9_DROME
# 2    OTF0003.1   A0JQ60_DROME_SELEX  A0JQ60_DROME
# 3    OTF0003.2  A0JQ60_DROME_DNaseI  A0JQ60_DROME
# 4    OTF0004.1     A1A6R5_DROME_B1H  A1A6R5_DROME
# 5    OTF0005.1  A1Z858_DROME_DNaseI  A1Z858_DROME
# 6    OTF0005.2     A1Z858_DROME_B1H  A1Z858_DROME
# 7    OTF0006.1     A1Z8F4_DROME_B1H  A1Z8F4_DROME
# 8    OTF0006.2  A1Z8F4_DROME_DNaseI  A1Z8F4_DROME
# 9    OTF0007.1     A1Z913_DROME_B1H  A1Z913_DROME
# 10   OTF0008.1     A1ZA01_DROME_B1H  A1ZA01_DROME
# 11   OTF0009.1  A1ZB05_DROME_DNaseI  A1ZB05_DROME
# 12   OTF0010.1     A1ZBV6_DROME_B1H  A1ZBV6_DROME
# 13   OTF0011.1     A2VEF7_DROME_B1H  A2VEF7_DROME
# 14   OTF0012.1     A4IJ65_DROME_B1H  A4IJ65_DROME
# 15   OTF0013.1     A4IJ80_DROME_B1H  A4IJ80_DROME
# 16   OTF0014.1     A4UZ51_DROME_B1H  A4UZ51_DROME
# 17   OTF0015.1  A4V1Y6_DROME_DNaseI  A4V1Y6_DROME
# 18   OTF0016.1  A4V1Y7_DROME_DNaseI  A4V1Y7_DROME
# 19   OTF0017.1     A4V304_DROME_B1H  A4V304_DROME
# 20   OTF0017.2  A4V304_DROME_DNaseI  A4V304_DROME
# 21   OTF0018.1     A4V334_DROME_B1H  A4V334_DROME
# 22   OTF0019.1     A4VCK2_DROME_B1H  A4VCK2_DROME
# 23   OTF0020.1     A7VJJ6_DROME_B1H  A7VJJ6_DROME
# 24   OTF0021.1  A8DY91_DROME_DNaseI  A8DY91_DROME
# 25   OTF0022.1     A8DYS7_DROME_B1H  A8DYS7_DROME
# 26   OTF0023.1  A8DYZ8_DROME_DNaseI  A8DYZ8_DROME
# 27   OTF0023.2     A8DYZ8_DROME_B1H  A8DYZ8_DROME
# 28   OTF0024.1     A8JUV3_DROME_B1H  A8JUV3_DROME
# 29   OTF0025.1  A8JUY5_DROME_DNaseI  A8JUY5_DROME
# ..         ...                  ...           ...
# 561  OTF0519.1     SUH_DROME_DNaseI     SUH_DROME
# 562  OTF0520.1        TAP_DROME_B1H     TAP_DROME
# 563  OTF0521.1     TIN_DROME_DNaseI     TIN_DROME
# 564  OTF0521.2        TIN_DROME_B1H     TIN_DROME
# 565  OTF0522.1        TKR_DROME_B1H     TKR_DROME
# 566  OTF0523.1     TLL_DROME_DNaseI     TLL_DROME
# 567  OTF0523.2        TLL_DROME_B1H     TLL_DROME
# 568  OTF0524.1    TTKA_DROME_DNaseI    TTKA_DROME
# 569  OTF0524.2       TTKA_DROME_B1H    TTKA_DROME
# 570  OTF0525.1    TTKB_DROME_DNaseI    TTKB_DROME
# 571  OTF0525.2       TTKB_DROME_B1H    TTKB_DROME
# 572  OTF0526.1    TWIST_DROME_SELEX   TWIST_DROME
# 573  OTF0526.2      TWIST_DROME_B1H   TWIST_DROME
# 574  OTF0526.3   TWIST_DROME_DNaseI   TWIST_DROME
# 575  OTF0527.1        UBX_DROME_B1H     UBX_DROME
# 576  OTF0527.2     UBX_DROME_DNaseI     UBX_DROME
# 577  OTF0528.1       UNC4_DROME_B1H    UNC4_DROME
# 578  OTF0529.1       UNPG_DROME_B1H    UNPG_DROME
# 579  OTF0530.1      USP_DROME_SELEX     USP_DROME
# 580  OTF0531.1        VND_DROME_B1H     VND_DROME
# 581  OTF0531.2     VND_DROME_DNaseI     VND_DROME
# 582  OTF0532.1       ZEN1_DROME_B1H    ZEN1_DROME
# 583  OTF0532.2    ZEN1_DROME_DNaseI    ZEN1_DROME
# 584  OTF0533.1       ZEN2_DROME_B1H    ZEN2_DROME
# 585  OTF0534.1    ZEST_DROME_DNaseI    ZEST_DROME
# 586  OTF0535.1     A0JQ60_DROME_B1H  A0JQ60_DROME
# 587  OTF0537.1      FBpp0081164_B1H   FBpp0081164
# 588  OTF0537.2   FBpp0081164_DNaseI   FBpp0081164
# 589  OTF0538.1   FBpp0099822_DNaseI   FBpp0099822
# 590  OTF0540.1     Q8WS79_DROME_B1H  Q8WS79_DROME
#
#                                                    url           id
# 0    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003651
# 1    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0034599
# 2    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000567
# 3    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000567
# 4    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0004914
# 5    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000448
# 6    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000448
# 7    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003396
# 8    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003396
# 9    https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0033748
# 10   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0034012
# 11   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0259211
# 12   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0034520
# 13   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000157
# 14   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0032587
# 15   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0020378
# 16   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000546
# 17   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0013263
# 18   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0013263
# 19   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000015
# 20   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000015
# 21   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0004652
# 22   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0036274
# 23   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0039411
# 24   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000448
# 25   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0005660
# 26   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0085424
# 27   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0085424
# 28   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0030505
# 29   https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003345
# ..                                                 ...          ...
# 561  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0004837
# 562  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0015550
# 563  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0004110
# 564  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0004110
# 565  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0266129
# 566  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003720
# 567  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003720
# 568  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003870
# 569  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003870
# 570  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003870
# 571  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003870
# 572  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003900
# 573  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003900
# 574  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003900
# 575  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003944
# 576  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003944
# 577  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0024184
# 578  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0015561
# 579  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003964
# 580  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0261930
# 581  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0261930
# 582  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0004053
# 583  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0004053
# 584  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0004054
# 585  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0004050
# 586  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000567
# 587  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000166
# 588  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0000166
# 589  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0003028
# 590  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0035849
#
# [591 rows x 5 columns]

# %%
for row in lee[['id', 'motif']].values:
    print(onTheFlyTFS[row[0]][0].oldID, row[1].split('.')[0])
# Out:
# OTF0001 OTF0001
# OTF0421 OTF0002
# OTF0112 OTF0003
# OTF0112 OTF0003
# OTF0004 OTF0004
# OTF0403 OTF0005
# OTF0403 OTF0005
# OTF0412 OTF0006
# OTF0412 OTF0006
# OTF0007 OTF0007
# OTF0008 OTF0008
# OTF0116 OTF0009
# OTF0401 OTF0010
# OTF0106 OTF0011
# OTF0012 OTF0012
# OTF0013 OTF0013
# OTF0014 OTF0014
# OTF0306 OTF0015
# OTF0306 OTF0016
# OTF0384 OTF0017
# OTF0384 OTF0017
# OTF0018 OTF0018
# OTF0019 OTF0019
# OTF0020 OTF0020
# OTF0403 OTF0021
# OTF0022 OTF0022
# OTF0023 OTF0023
# OTF0023 OTF0023
# OTF0024 OTF0024
# OTF0508 OTF0025
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-f9cfe1a84d80> in <module>()
#       1 for row in lee[['id', 'motif']].values:
# ----> 2     print(onTheFlyTFS[row[0]][0].oldID, row[1].split('.')[0])
#
# /Users/fearjm/Projects/s2rnai/lib/python/meme.py in __getitem__(self, key)
#      32
#      33     def __getitem__(self, key):
# ---> 34         return self.tfs[key]
#      35
#      36     def __iter__(self):
#
# KeyError: 'FBgn0262656'

# %%
m = onTheFlyTFS['FBgn0262656']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-1da45ecbfd07> in <module>()
# ----> 1 m = onTheFlyTFS['FBgn0262656']
#
# /Users/fearjm/Projects/s2rnai/lib/python/meme.py in __getitem__(self, key)
#      32
#      33     def __getitem__(self, key):
# ---> 34         return self.tfs[key]
#      35
#      36     def __iter__(self):
#
# KeyError: 'FBgn0262656'

# %%
lee[lee['id'] == 'FBgn0262656']
# Out:
#         motif           summary       uniprot  \
# 30  OTF0026.1  A8VEM3_DROME_B1H  A8VEM3_DROME
#
#                                                   url           id
# 30  https://bhapp.c2b2.columbia.edu/OnTheFly/cgi-b...  FBgn0262656

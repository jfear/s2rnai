# %% [markdown]
# Today I am checking Isabelle's modEncode results table. I want to see what kinds of datasets we have and figure why we are missing some datasets from the website.

# %%
# %load ../start.py
# Load useful extensions
import os
import sys

# Activate the autoreload extension for easy reloading of external packages
# %reload_ext autoreload
# %autoreload 1

# Set up cashdir
from ipycache import CacheMagics
CacheMagics.cachedir = '../cachedir'

# Trun on the water mark
# %reload_ext watermark
# %watermark -u -d -v -g

# Load ipycache extension
# %reload_ext ipycache
from ipycache import CacheMagics
CacheMagics.cachedir = '../cachedir'

# Add project library to path
sys.path.insert(0, '../../lcdb-wf/lib')
sys.path.insert(0, '../../lib/python')

# Set up references
import yaml
with open('../../config/config.yml') as fh:
    config = yaml.load(fh)

assembly = config['assembly']
tag = config['aligner']['tag']
REF = os.path.join(os.environ['REFERENCES_DIR'], assembly, tag)
# Out:
# last updated: 2017-09-12
#
# CPython 3.5.2
# IPython 6.1.0
# Git hash: 30a5c2596ed0b2a6df8b58fe4ad3d7ee3e26839d

# %%
# Imports
import pandas as pd
from intermine.webservice import Service

# %%
# Query modMine
## connect to web service
service = Service("http://intermine.modencode.org/release-33/service")

# Get a new query:
query = service.new_query("Submission")

# The view specifies the output columns
query.add_view(
    "DCCid", "assayFactor", "title", "lab.name", "experimentalFactors.type",
    "experimentalFactors.name"
)

# You can edit the constraint values below
query.add_constraint("experimentType", "=", "ChIP-seq", code = "A")
query.add_constraint("organism.species", "=", "melanogaster", code = "B")

# Make data frame of results.
df = pd.DataFrame([x.to_d() for x in query.rows()])

# %%
# Import Isabelle's final table of modEnocde peaks.
isaDf = pd.read_csv('../../output/modENCODE_finaltable', sep='\t', header=None, low_memory=False)
isaDf.columns = [
    'name', 
    'score', 
    'chrom', 
    'start', 
    'end', 
    'strand',
    'modENCODE_id',
    'peak_fbgn',
    'peak_symbol', 
    'antibody',
    'cell_line',
    'dev_stage',
    'strain',
    'target_gene',
    'tissue',
    'TF_name',
    'TF_fbgn'
]

# %%
# Check overlap
## Convert IDs to sets
isa_ids = set(isaDf.modENCODE_id.unique().tolist())
modEncode_ids = set(df['Submission.DCCid'].unique().tolist())

## look at intersection and overlap
intersect = modEncode_ids.intersection(isa_ids)
difference = modEncode_ids.difference(isa_ids)
print(
    "Isabelle IDs: {}\n"
    "modEncode IDs: {}\n"
    "Overlapping IDs: {}\n"
    "Differeng IDs: {}".format(
        len(isa_ids),
        len(modEncode_ids),
        len(intersect),
        len(difference)
    )
 )
# Out:
# Isabelle IDs: 107
# modEncode IDs: 351
# Overlapping IDs: 107
# Differeng IDs: 244

# %%
# Get more details about missing cells and dev stage
missing = df['Submission.DCCid'].isin(list(difference))
there = df['Submission.DCCid'].isin(list(intersect))
dev_stage = df['Submission.experimentalFactors.type'] == 'developmental stage'
cell_line = df['Submission.experimentalFactors.type'] == 'cell line'

df['Isabelle'] = False
df.loc[there, 'Isabelle'] = True

df['Missing'] = False
df.loc[missing, 'Missing'] = True

# Make summary Table
df.loc[
        (dev_stage|cell_line), 
        ['Isabelle', 'Missing', 'Submission.experimentalFactors.name']
      ].groupby('Submission.experimentalFactors.name').sum().applymap(lambda x: int(x))
# Out:
#                                      Isabelle  Missing
# Submission.experimentalFactors.name
# 3rd Instar Larvae                          13       25
# Adult Female                                2        5
# Adult Male                                  0        6
# CME W1 Cl.8+                                3        1
# Embryo 0-12 h                               6        8
# Embryo 0-4 h                                0       15
# Embryo 0-8 h                                9        5
# Embryo 1-6 h                                1        1
# Embryo 12-16 h                              0        8
# Embryo 12-24 h                              2        1
# Embryo 14-16hr OR                          25       25
# Embryo 16-20 h                              0        8
# Embryo 16-24 h                              9        4
# Embryo 20-24 h                              0        8
# Embryo 4-7 h                                0        1
# Embryo 4-8 h                                0        8
# Embryo 8-12 h                               0        8
# Embryo 8-16 h                               7        6
# Kc167                                       3        6
# L1 stage larvae                             0        8
# L2 stage larvae                             0        8
# L3 stage larvae                             5       16
# L3 stage wandering larvae                   0        1
# ML-DmBG3-c2                                 0        1
# Mixed Adults 22 days AEL                   12       27
# Pupae                                       0        8
# S2-DRSC                                     0       13
# White prepupae (WPP)                        7        1
# White prepupae (WPP) + 4-5h                 1        0
# White prepupae (WPP) 10-11                  0        1
# White prepupae (WPP) 30-33h                 0        1
# White prepupae (WPP)+12                     1        0

# %%
# Get more details about missing tissues
tissue = df['Submission.experimentalFactors.type'] == 'tissue'

df['Isabelle'] = False
df.loc[there, 'Isabelle'] = True

df['Missing'] = False
df.loc[missing, 'Missing'] = True

# Make summary Table
df.loc[
        tissue, 
        ['Isabelle', 'Missing', 'Submission.experimentalFactors.name']
      ].groupby('Submission.experimentalFactors.name').sum().applymap(lambda x: int(x))
# Out:
#                                      Isabelle  Missing
# Submission.experimentalFactors.name
# Heads OR                                   12       27
# salivary glands                             0        1

# %%
df.columns
# Out:
# Index(['Submission.DCCid', 'Submission.RNAsize', 'Submission.assayFactor',
#        'Submission.description', 'Submission.design', 'Submission.embargoDate',
#        'Submission.experimentDate', 'Submission.experimentType',
#        'Submission.experimentalFactors.name',
#        'Submission.experimentalFactors.type', 'Submission.id',
#        'Submission.lab.name', 'Submission.multiplyMappedReadCount',
#        'Submission.name', 'Submission.notice', 'Submission.publicReleaseDate',
#        'Submission.qualityControl', 'Submission.replacesSubmission',
#        'Submission.replicate', 'Submission.title',
#        'Submission.totalMappedReadCount', 'Submission.totalReadCount',
#        'Submission.uniquelyMappedReadCount', 'Submission.url',
#        'Submission.version', 'Isabelle', 'Missing'],
#       dtype='object')

# %%
df.loc[tissue, 'Submission.experimentalFactors.name'].unique()
# Out:
# array(['salivary glands', 'Heads OR'], dtype=object)

# %%
df[df['Submission.DCCid'] == 'modENCODE_6389']
# Out:
#     Submission.DCCid Submission.RNAsize Submission.assayFactor  \
# 842   modENCODE_6389               None               H3K36me2
# 843   modENCODE_6389               None               H3K36me2
#
#                                 Submission.description  \
# 842  We aim to determine the locations of the major...
# 843  We aim to determine the locations of the major...
#
#                       Submission.design        Submission.embargoDate  \
# 842  binding_site_identification_design  Wed Mar 06 00:00:00 UTC 2013
# 843  binding_site_identification_design  Wed Mar 06 00:00:00 UTC 2013
#
#         Submission.experimentDate Submission.experimentType  \
# 842  Sat Apr 14 00:00:00 UTC 2012                  ChIP-seq
# 843  Sat Apr 14 00:00:00 UTC 2012                  ChIP-seq
#
#     Submission.experimentalFactors.name Submission.experimentalFactors.type  \
# 842                          H3K36me2_W                            antibody
# 843                         ML-DmBG3-c2                           cell line
#
#       ...    Submission.replacesSubmission  Submission.replicate  \
# 842   ...                             None  biological_replicate
# 843   ...                             None  biological_replicate
#
#           Submission.title Submission.totalMappedReadCount  \
# 842  H3K36me2_W.BG3.Solexa                      52409495.0
# 843  H3K36me2_W.BG3.Solexa                      52409495.0
#
#     Submission.totalReadCount Submission.uniquelyMappedReadCount  \
# 842                73107572.0                         52409495.0
# 843                73107572.0                         52409495.0
#
#     Submission.url Submission.version Isabelle Missing
# 842           None               None    False    True
# 843           None               None    False    True
#
# [2 rows x 27 columns]

# %%
df[df['Submission.experimentalFactors.name'] == 'S2-DRSC']
# Out:
#     Submission.DCCid Submission.RNAsize Submission.assayFactor  \
# 30    modENCODE_2638               None                   CTCF
# 33    modENCODE_2639               None                   CTCF
# 47    modENCODE_2979               None                 MCM2-7
# 75    modENCODE_3189               None               H3K36me3
# 212   modENCODE_3953               None                H3K9me2
# 344   modENCODE_4715               None               H3K36me3
# 346   modENCODE_4716               None                 Su(Hw)
# 425   modENCODE_4966               None                 CG8478
# 445   modENCODE_4985               None                H3K4me1
# 453   modENCODE_4988               None                H3K4me3
# 479   modENCODE_5007               None                     dm
# 820   modENCODE_5595               None                   H2Av
# 823   modENCODE_5596               None                   H2Av
#
#                                 Submission.description  \
# 30   The White Lab is aiming to map the association...
# 33   The White Lab is aiming to map the association...
# 47   We will precisely identify sequence elements t...
# 75   The White Lab is aiming to map the association...
# 212  We aim to determine the locations of the major...
# 344  Chromatin immunoprecipitation (ChIP) followed ...
# 346  Chromatin immunoprecipitation (ChIP) followed ...
# 425  The White Lab is aiming to map the association...
# 445  The White Lab is aiming to map the association...
# 453  The White Lab is aiming to map the association...
# 479  The White Lab is aiming to map the association...
# 820  The goal of these experiments are to a) valida...
# 823  The goal of these experiments are to a) valida...
#
#                       Submission.design        Submission.embargoDate  \
# 30   binding_site_identification_design  Mon Oct 25 00:00:00 UTC 2010
# 33   binding_site_identification_design  Mon Oct 25 00:00:00 UTC 2010
# 47   binding_site_identification_design  Tue Apr 05 00:00:00 UTC 2011
# 75   binding_site_identification_design  Thu Jun 09 00:00:00 UTC 2011
# 212  binding_site_identification_design  Sat Jun 30 00:00:00 UTC 2012
# 344  binding_site_identification_design  Fri Dec 07 00:00:00 UTC 2012
# 346  binding_site_identification_design  Wed Dec 26 00:00:00 UTC 2012
# 425  binding_site_identification_design  Fri Jan 11 00:00:00 UTC 2013
# 445  binding_site_identification_design  Sat Jan 12 00:00:00 UTC 2013
# 453  binding_site_identification_design  Sat Jan 12 00:00:00 UTC 2013
# 479  binding_site_identification_design  Sat Jan 12 00:00:00 UTC 2013
# 820  binding_site_identification_design  Wed Mar 06 00:00:00 UTC 2013
# 823  binding_site_identification_design  Wed Mar 06 00:00:00 UTC 2013
#
#         Submission.experimentDate Submission.experimentType  \
# 30   Tue Jan 26 00:00:00 UTC 2010                  ChIP-seq
# 33   Tue Jan 26 00:00:00 UTC 2010                  ChIP-seq
# 47   Fri Feb 13 00:00:00 UTC 2009                  ChIP-seq
# 75   Mon May 13 00:00:00 UTC 2013                  ChIP-seq
# 212  Thu Mar 29 00:00:00 UTC 2012                  ChIP-seq
# 344  Mon Mar 26 00:00:00 UTC 2012                  ChIP-seq
# 346  Tue Mar 27 00:00:00 UTC 2012                  ChIP-seq
# 425  Thu Aug 15 00:00:00 UTC 2013                  ChIP-seq
# 445  Thu Aug 15 00:00:00 UTC 2013                  ChIP-seq
# 453  Fri Aug 16 00:00:00 UTC 2013                  ChIP-seq
# 479  Fri Aug 16 00:00:00 UTC 2013                  ChIP-seq
# 820  Tue May 29 00:00:00 UTC 2012                  ChIP-seq
# 823  Tue May 29 00:00:00 UTC 2012                  ChIP-seq
#
#     Submission.experimentalFactors.name Submission.experimentalFactors.type  \
# 30                              S2-DRSC                           cell line
# 33                              S2-DRSC                           cell line
# 47                              S2-DRSC                           cell line
# 75                              S2-DRSC                           cell line
# 212                             S2-DRSC                           cell line
# 344                             S2-DRSC                           cell line
# 346                             S2-DRSC                           cell line
# 425                             S2-DRSC                           cell line
# 445                             S2-DRSC                           cell line
# 453                             S2-DRSC                           cell line
# 479                             S2-DRSC                           cell line
# 820                             S2-DRSC                           cell line
# 823                             S2-DRSC                           cell line
#
#       ...    Submission.replacesSubmission  Submission.replicate  \
# 30    ...                             None  biological_replicate
# 33    ...                             None  biological_replicate
# 47    ...                             None  biological_replicate
# 75    ...                             None  biological_replicate
# 212   ...                             None  biological_replicate
# 344   ...                             None   technical_replicate
# 346   ...                             None   technical_replicate
# 425   ...                             None  biological_replicate
# 445   ...                             None  biological_replicate
# 453   ...                             None  biological_replicate
# 479   ...                             None  biological_replicate
# 820   ...                             None  biological_replicate
# 823   ...                             None  biological_replicate
#
#                                       Submission.title  \
# 30                                 S2_CTCF200_ChIP-seq
# 33                                 S2_CTCF500_ChIP-seq
# 47                                    MCM S2 July 2010
# 75                         H3K36me3_S2_cells_ChIP-chip
# 212                        Solexa.H3K9me2_antibody2.S2
# 344  Ultra-deep ChIP-seq of H3K36me3 in D. melanoga...
# 346  Ultra-deep ChIP-seq of Su(Hw) in D. melanogast...
# 425                           CG8478_S2_cells_ChIP-seq
# 445                          H3K4me1_S2_cells_ChIP-seq
# 453                          H3K4me3_S2_cells_ChIP-seq
# 479                             dMyc_S2_cells_ChIP-seq
# 820                      H2AV-9751.S2.H2AV_RNAi.Solexa
# 823                       H2AV-9751.S2.GFP_RNAi.Solexa
#
#     Submission.totalMappedReadCount Submission.totalReadCount  \
# 30                              NaN                       NaN
# 33                              NaN                       NaN
# 47                              NaN                54687237.0
# 75                              NaN                       NaN
# 212                      28960378.0                58418187.0
# 344                             NaN                       NaN
# 346                             NaN                       NaN
# 425                      57186237.0                64502447.0
# 445                      68445159.0                76134721.0
# 453                      76388085.0                82001205.0
# 479                      43719552.0                61545123.0
# 820                      43101821.0                58026997.0
# 823                      40621516.0                56281543.0
#
#     Submission.uniquelyMappedReadCount Submission.url Submission.version  \
# 30                                 NaN           None               None
# 33                                 NaN           None               None
# 47                          38822184.0           None               None
# 75                                 NaN           None               None
# 212                         28960378.0           None               None
# 344                                NaN           None               None
# 346                                NaN           None               None
# 425                         57186237.0           None               None
# 445                         68445159.0           None               None
# 453                         76388085.0           None               None
# 479                         43719552.0           None               None
# 820                         43101821.0           None               None
# 823                         40621516.0           None               None
#
#     Isabelle Missing
# 30     False    True
# 33     False    True
# 47     False    True
# 75     False    True
# 212    False    True
# 344    False    True
# 346    False    True
# 425    False    True
# 445    False    True
# 453    False    True
# 479    False    True
# 820    False    True
# 823    False    True
#
# [13 rows x 27 columns]

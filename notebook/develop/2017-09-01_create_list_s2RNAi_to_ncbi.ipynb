# %%
# %load ../start.py
# Load useful extensions

# Activate the autoreload extension for easy reloading of external packages
# %reload_ext autoreload
# %autoreload 1

# Set up cashdir
from ipycache import CacheMagics
CacheMagics.cachedir = '../cachedir'

# Trun on the water mark
# %reload_ext watermark
# %watermark -u -d -v -g

# Load ipycache extension
# %reload_ext ipycache
from ipycache import CacheMagics
CacheMagics.cachedir = '../cachedir'

# Add project library to path
import sys
sys.path.insert(0, '../../lcdb-wf/lib')
sys.path.insert(0, '../../lib/python')

import yaml
with open('../../config/config.yml') as fh:
    config = yaml.load(fh)
# Out:
# last updated: 2017-09-01
#
# CPython 3.5.4
# IPython 6.1.0
# Git hash: b1807333b845adb20912da5246c0c8754330f435

# %%
# imports
import os
import re
from tempfile import TemporaryDirectory
import pandas as pd
import numpy as np

import GEOparse

# %%
# load flybase annotations

# %%
fb = pd.read_table(os.path.join(os.environ['REFERENCES_DIR']))

# %%
# !ls $REFERENCES_DIR/dmel/r6-16/

# %%
config.keys()
# Out:
# dict_keys(['assembly', 'rrna', 'references', 'kallisto', 'aggregation_dir', 'sampletable', 'gtf', 'sample_dir', 'aligner'])

# %%
config['references']['dmel']['r6-16']
# Out:
# {'fasta': {'indexes': ['bowtie2', 'hisat2'],
#   'postprocess': 'lib.postprocess.dm6.fasta_postprocess',
#   'url': 'ftp://ftp.flybase.net/genomes/Drosophila_melanogaster/dmel_r6.16_FB2017_03/fasta/dmel-all-chromosome-r6.16.fasta.gz'},
#  'gtf': {'conversions': ['refflat',
#    {'gffutils': {'disable_infer_genes': True,
#      'gtf_gene_key': 'gene_id',
#      'gtf_transcript_key': 'transcript_id',
#      'id_spec': {'gene': ['gene_id', 'gene_symbol'],
#       'transcript': ['transcript_id', 'transcript_symbol']},
#      'merge_strategy': 'merge'}},
#    {'genelist': {'gene_id': 'gene_id'}},
#    {'annotation_hub': {'ahkey': 'AH49581', 'keytype': 'ENSEMBL'}}],
#   'postprocess': 'lib.postprocess.dm6.gtf_postprocess',
#   'url': 'ftp://ftp.flybase.net/genomes/Drosophila_melanogaster/dmel_r6.16_FB2017_03/gtf/dmel-all-r6.16.gtf.gz'}}

# %%
from common import references_dict

# %%
references_dict(config)[0]['dmel']['r6-16'].keys()
# Out:
# dict_keys(['gtf', 'hisat2', 'gffutils', 'bowtie2', 'genelist', 'chromsizes', 'refflat', 'fasta', 'annotation_hub'])

# %%
# Build sample table
# Query GEO 
gse = GEOparse.get_GEO(geo="GSE81221", silent=True)

# Pull out sample attributes and build data frame
attributes = []
for gsm, dat in gse.gsms.items():
    try:
        attrs = re.match(r'^.*_(?P<fbgn>FBgn(\d+|NA))_(?P<symbol>.*?)_.*(?P<drsc>DRSC(\d+|NA))_replicate(?P<rep>\d)(\s\[Plate(?P<plate_id>\d+)-\d_F3\]|$)', dat.metadata['title'][0]).groupdict()
    except AttributeError:
        print(gsm, dat.metadata['title'])
        
    attrs['GEO'] = gsm
    attrs.update(re.match(r'.*_DRSC_Plate(?P<plate_id>\d+)-\d_(?P<well_id>\w\d+)_.*', 
                          dat.metadata['supplementary_file_2'][0]).groupdict())
    
    attrs.update(re.match(r'(?P<plate_row>\w)(?P<plate_column>\d+)', attrs['well_id']).groupdict())

    for x in dat.metadata['relation']:
        k, v = re.match(r'(\w+):.*[\/=](\w+\d+)$', x).groups()
        attrs[k] = v
    attributes.append(attrs)

df = pd.DataFrame(attributes)

df.set_index('SRA', inplace=True)
cols = [
    'BioSample', 'GEO', 'drsc', 'fbgn', 'symbol', 'rep',
    'plate_id', 'well_id', 'plate_row', 'plate_column'
]
df = df[cols]

# %%
# Sanity check FBgns for changes

# %%
# import FBgn to symbol
db = gffutils.FeatureDB(
    os.path.join(os.environ['REFERENCES_DIR'], 'dmel/r6-11/gtf/dmel_r6-11.gtf.db'))

genes = []
for gene in db.features_of_type(featuretype='gene'):
    fbgn = gene.id
    symbol = gene.attributes['gene_symbol'][0].replace('(', '[').replace(')', ']')
    genes.append({'FBgn': fbgn, 'r6-11_symbol': symbol})

fb = pd.DataFrame(genes)
fb.set_index('FBgn', inplace=True)

# %%
merged = df.merge(fb, how='left', left_on='fbgn', right_index=True)
merged[(merged.symbol != merged['r6-11_symbol'])]
# Out:
#                BioSample         GEO       drsc         fbgn   symbol rep  \
# SRA
# SRX1749426  SAMN04959619  GSM2145690  DRSC20029  FBgn0085451  CG34422   1
# SRX1748909  SAMN04959132  GSM2145175  DRSC04554  FBgn0026582   CG9418   1
# SRX1750082  SAMN04960612  GSM2146343  DRSC18419  FBgn0030093    dalao   2
# SRX1749968  SAMN04960053  GSM2146230  DRSC26287  FBgn0032940      Mio   2
# SRX1748894  SAMN04959118  GSM2145161     DRSCNA       FBgnNA     LacZ   1
# SRX1749370  SAMN04959441  GSM2145634  DRSC02668  FBgn0032940      Mio   2
# SRX1749364  SAMN04959435  GSM2145628  DRSC08367  FBgn0035160  CG13897   2
# SRX1750341  SAMN04960902  GSM2146601  DRSC37496  FBgn0085451  CG34422   2
# SRX1749224  SAMN04959791  GSM2145489  DRSC11182  FBgn0261283   HLH106   1
# SRX1750381  SAMN04960761  GSM2146641  DRSC37996  FBgn0035407  CG14962   1
# SRX1749042  SAMN04959537  GSM2145308  DRSC16349  FBgn0039740   CG7928   1
# SRX1749477  SAMN04960134  GSM2145741  DRSC16412  FBgn0037634   CG8359   1
# SRX1749744  SAMN04960221  GSM2146007  DRSC23360  FBgn0262656       dm   2
# SRX1750271  SAMN04960862  GSM2146531  DRSC37499  FBgn0039740   CG7928   2
# SRX1749796  SAMN04960482  GSM2146058  DRSC27862  FBgn0005630     lola   1
# SRX1749429  SAMN04959622  GSM2145693  DRSC16389  FBgn0037617   CG8145   1
# SRX1749452  SAMN04960440  GSM2145716  DRSC22734  FBgn0267791       bl   1
# SRX1749267  SAMN04959804  GSM2145532  DRSC07647  FBgn0005630     lola   1
# SRX1748679  SAMN04959393  GSM2144946  DRSC11048  FBgn0052133     ptip   1
# SRX1750545  SAMN04960538  GSM2146804  DRSC14626  FBgn0039209  CG13624   2
# SRX1750391  SAMN04960772  GSM2146651  DRSC24359  FBgn0039209  CG13624   1
# SRX1749366  SAMN04959437  GSM2145630  DRSC10660  FBgn0052133     ptip   2
# SRX1750081  SAMN04960611  GSM2146342  DRSC02642  FBgn0032600  CG17912   2
# SRX1749400  SAMN04959696  GSM2145664  DRSC08479  FBgn0035405      pfk   2
# SRX1749944  SAMN04960089  GSM2146206     DRSCNA       FBgnNA     LacZ   2
# SRX1750366  SAMN04960927  GSM2146626  DRSC08421  FBgn0035407  CG14962   1
# SRX1750499  SAMN04960819  GSM2146758  DRSC25285  FBgn0032600  CG17912   2
# SRX1749524  SAMN04960272  GSM2145788  DRSC16389  FBgn0037617   CG8145   2
# SRX1749138  SAMN04959450  GSM2145403  DRSC16349  FBgn0039740   CG7928   2
# SRX1750492  SAMN04960992  GSM2146751  DRSC37606  FBgn0036134    fd68A   2
# ...                  ...         ...        ...          ...      ...  ..
# SRX1748704  SAMN04959088  GSM2144971     DRSCNA       FBgnNA     LacZ   1
# SRX1749575  SAMN04960292  GSM2145838  DRSC14529  FBgn0039411      dys   2
# SRX1749860  SAMN04960005  GSM2146122  DRSC26026  FBgn0037617   CG8145   1
# SRX1750326  SAMN04960887  GSM2146586     DRSCNA       FBgnNA     LacZ   2
# SRX1749479  SAMN04960136  GSM2145743  DRSC14529  FBgn0039411      dys   1
# SRX1749268  SAMN04959805  GSM2145533  DRSC08367  FBgn0035160  CG13897   1
# SRX1750040  SAMN04959969  GSM2146301     DRSCNA       FBgnNA     LacZ   1
# SRX1749733  SAMN04960211  GSM2145996  DRSC24070  FBgn0267791       bl   2
# SRX1749319  SAMN04959856  GSM2145584  DRSC11182  FBgn0261283   HLH106   2
# SRX1749421  SAMN04959614  GSM2145685  DRSC14896  FBgn0039411      dys   1
# SRX1750409  SAMN04960668  GSM2146669  DRSC37620  FBgn0035405      pfk   1
# SRX1749493  SAMN04960151  GSM2145757  DRSC15691  FBgn0039559    Mes-4   1
# SRX1749363  SAMN04959434  GSM2145627  DRSC07647  FBgn0005630     lola   2
# SRX1750403  SAMN04960662  GSM2146663  DRSC25285  FBgn0032600  CG17912   1
# SRX1750505  SAMN04960825  GSM2146764  DRSC37620  FBgn0035405      pfk   2
# SRX1750396  SAMN04960777  GSM2146656  DRSC37606  FBgn0036134    fd68A   1
# SRX1749870  SAMN04960015  GSM2146132  DRSC28822  FBgn0030093    dalao   1
# SRX1748921  SAMN04959144  GSM2145187  DRSC04555  FBgn0034599   CG9437   1
# SRX1748774  SAMN04959261  GSM2145041  DRSC11048  FBgn0052133     ptip   2
# SRX1750016  SAMN04959951  GSM2146277  DRSC29262  FBgn0035160  CG13897   1
# SRX1750231  SAMN04960731  GSM2146491     DRSCNA       FBgnNA     LacZ   1
# SRX1749955  SAMN04960040  GSM2146217  DRSC26026  FBgn0037617   CG8145   2
# SRX1749891  SAMN04960096  GSM2146153  DRSC27862  FBgn0005630     lola   2
# SRX1749304  SAMN04959841  GSM2145569  DRSC08479  FBgn0035405      pfk   1
# SRX1750135  SAMN04960574  GSM2146396     DRSCNA       FBgnNA     LacZ   2
# SRX1748799  SAMN04959344  GSM2145066     DRSCNA       FBgnNA     LacZ   2
# SRX1749516  SAMN04960264  GSM2145780  DRSC14896  FBgn0039411      dys   2
# SRX1749638  SAMN04960175  GSM2145901  DRSC24070  FBgn0267791       bl   1
# SRX1749629  SAMN04960166  GSM2145892  DRSC24971  FBgn0036134    fd68A   1
# SRX1749557  SAMN04960425  GSM2145820  DRSC20321  FBgn0030891      dik   2
#
#            plate_id well_id plate_row plate_column r6-11_symbol
# SRA
# SRX1749426        4      B9         B            9          htk
# SRX1748909        1      G5         G            5        Hmg-2
# SRX1750082        7      A9         A            9       Bap111
# SRX1749968        6      H3         H            3        Mondo
# SRX1748894        1      F3         F            3          NaN
# SRX1749370        3      F1         F            1        Mondo
# SRX1749364        3      E7         E            7         hng3
# SRX1750341        8      G6         G            6          htk
# SRX1749224        3     B10         B           10        SREBP
# SRX1750381        9     C11         C           11        Asciz
# SRX1749042        2      B7         B            7        ZIPIC
# SRX1749477        4      G1         G            1         hng2
# SRX1749744        5      E6         E            6          Myc
# SRX1750271        8      A7         A            7        ZIPIC
# SRX1749796        6      A9         A            9          NaN
# SRX1749429        4      C1         C            1          nom
# SRX1749452        4     E12         E           12      HnRNP-K
# SRX1749267        3      E6         E            6          NaN
# SRX1748679       10      D2         D            2         Ptip
# SRX1750545        9      H7         H            7       REPTOR
# SRX1750391        9      C9         C            9       REPTOR
# SRX1749366        3      E9         E            9         Ptip
# SRX1750081        7      A8         A            8         BuGZ
# SRX1749400        3      H7         H            7      CG15812
# SRX1749944        6      F3         F            3          NaN
# SRX1750366        9      A7         A            7        Asciz
# SRX1750499        9      D9         D            9         BuGZ
# SRX1749524        4      C1         C            1          nom
# SRX1749138        2      B7         B            7        ZIPIC
# SRX1750492        9      D2         D            2         FoxK
# ...             ...     ...       ...          ...          ...
# SRX1748704       10      F3         F            3          NaN
# SRX1749575        4      G3         G            3         dysf
# SRX1749860        6      G2         G            2          nom
# SRX1750326        8      F3         F            3          NaN
# SRX1749479        4      G3         G            3         dysf
# SRX1749268        3      E7         E            7         hng3
# SRX1750040        7      F3         F            3          NaN
# SRX1749733        5      D7         D            7      HnRNP-K
# SRX1749319        3     B10         B           10        SREBP
# SRX1749421        4      B4         B            4         dysf
# SRX1750409        9      E3         E            3      CG15812
# SRX1749493        4      H5         H            5          NSD
# SRX1749363        3      E6         E            6          NaN
# SRX1750403        9      D9         D            9         BuGZ
# SRX1750505        9      E3         E            3      CG15812
# SRX1750396        9      D2         D            2         FoxK
# SRX1749870        6     H12         H           12       Bap111
# SRX1748921        1      H5         H            5         hng1
# SRX1748774       10      D2         D            2         Ptip
# SRX1750016        7      D3         D            3         hng3
# SRX1750231        8      F3         F            3          NaN
# SRX1749955        6      G2         G            2          nom
# SRX1749891        6      A9         A            9          NaN
# SRX1749304        3      H7         H            7      CG15812
# SRX1750135        7      F3         F            3          NaN
# SRX1748799       10      F3         F            3          NaN
# SRX1749516        4      B4         B            4         dysf
# SRX1749638        5      D7         D            7      HnRNP-K
# SRX1749629        5     D10         D           10         FoxK
# SRX1749557        4      E9         E            9         Ada3
#
# [112 rows x 11 columns]

# %%
merged[merged['r6-11_symbol'].isnull()]
# Out:
#                BioSample         GEO       drsc         fbgn symbol rep  \
# SRA
# SRX1748894  SAMN04959118  GSM2145161     DRSCNA       FBgnNA   LacZ   1
# SRX1749796  SAMN04960482  GSM2146058  DRSC27862  FBgn0005630   lola   1
# SRX1749267  SAMN04959804  GSM2145532  DRSC07647  FBgn0005630   lola   1
# SRX1749944  SAMN04960089  GSM2146206     DRSCNA       FBgnNA   LacZ   2
# SRX1749276  SAMN04959813  GSM2145541     DRSCNA       FBgnNA   LacZ   1
# SRX1748990  SAMN04959545  GSM2145256     DRSCNA       FBgnNA   LacZ   2
# SRX1749467  SAMN04960126  GSM2145731     DRSCNA       FBgnNA   LacZ   1
# SRX1750421  SAMN04960680  GSM2146681     DRSCNA       FBgnNA   LacZ   1
# SRX1749658  SAMN04960345  GSM2145921     DRSCNA       FBgnNA   LacZ   1
# SRX1749753  SAMN04960230  GSM2146016     DRSCNA       FBgnNA   LacZ   2
# SRX1750517  SAMN04960838  GSM2146776     DRSCNA       FBgnNA   LacZ   2
# SRX1749372  SAMN04959443  GSM2145636     DRSCNA       FBgnNA   LacZ   2
# SRX1749563  SAMN04960424  GSM2145826     DRSCNA       FBgnNA   LacZ   2
# SRX1749849  SAMN04959905  GSM2146111     DRSCNA       FBgnNA   LacZ   1
# SRX1749085  SAMN04959640  GSM2145351     DRSCNA       FBgnNA   LacZ   1
# SRX1749181  SAMN04959495  GSM2145446     DRSCNA       FBgnNA   LacZ   2
# SRX1748704  SAMN04959088  GSM2144971     DRSCNA       FBgnNA   LacZ   1
# SRX1750326  SAMN04960887  GSM2146586     DRSCNA       FBgnNA   LacZ   2
# SRX1750040  SAMN04959969  GSM2146301     DRSCNA       FBgnNA   LacZ   1
# SRX1749363  SAMN04959434  GSM2145627  DRSC07647  FBgn0005630   lola   2
# SRX1750231  SAMN04960731  GSM2146491     DRSCNA       FBgnNA   LacZ   1
# SRX1749891  SAMN04960096  GSM2146153  DRSC27862  FBgn0005630   lola   2
# SRX1750135  SAMN04960574  GSM2146396     DRSCNA       FBgnNA   LacZ   2
# SRX1748799  SAMN04959344  GSM2145066     DRSCNA       FBgnNA   LacZ   2
#
#            plate_id well_id plate_row plate_column r6-11_symbol
# SRA
# SRX1748894        1      F3         F            3          NaN
# SRX1749796        6      A9         A            9          NaN
# SRX1749267        3      E6         E            6          NaN
# SRX1749944        6      F3         F            3          NaN
# SRX1749276        3      F3         F            3          NaN
# SRX1748990        1      F3         F            3          NaN
# SRX1749467        4      F3         F            3          NaN
# SRX1750421        9      F3         F            3          NaN
# SRX1749658        5      F3         F            3          NaN
# SRX1749753        5      F3         F            3          NaN
# SRX1750517        9      F3         F            3          NaN
# SRX1749372        3      F3         F            3          NaN
# SRX1749563        4      F3         F            3          NaN
# SRX1749849        6      F3         F            3          NaN
# SRX1749085        2      F3         F            3          NaN
# SRX1749181        2      F3         F            3          NaN
# SRX1748704       10      F3         F            3          NaN
# SRX1750326        8      F3         F            3          NaN
# SRX1750040        7      F3         F            3          NaN
# SRX1749363        3      E6         E            6          NaN
# SRX1750231        8      F3         F            3          NaN
# SRX1749891        6      A9         A            9          NaN
# SRX1750135        7      F3         F            3          NaN
# SRX1748799       10      F3         F            3          NaN

# %%
from tempfile import NamedTemporaryFile
import urllib

# %%
urllib.request.urlopen()

# %%
from common import get_references_dir

# %%
import yaml

# %%
with open('../../config/config.yml') as fh:
    config = yaml.load(fh)

# %%
config
# Out:
# {'aggregation_dir': 'data/aggregation',
#  'aligner': {'index': 'hisat2', 'tag': 'r6-16'},
#  'assembly': 'dmel',
#  'gtf': {'tag': 'r6-16'},
#  'kallisto': {'tag': 'r6-16_transcriptome'},
#  'references': {'adapters': {'default': {'fasta': {'indexes': ['bowtie2'],
#      'postprocess': 'lib.postprocess.adapters.fasta_postprocess',
#      'url': 'https://raw.githubusercontent.com/lcdb/lcdb-test-data/master/data/seq/adapters.fa'}}},
#   'dicty': {'ensembl_2.7': {'fasta': {'indexes': ['bowtie2', 'hisat2'],
#      'url': 'ftp://ftp.ensemblgenomes.org/pub/protists/release-33/fasta/dictyostelium_discoideum/dna/Dictyostelium_discoideum.dicty_2.7.dna_sm.toplevel.fa.gz'}},
#    'ensembl_2.7.33': {'gtf': {'conversions': ['refflat'],
#      'url': 'ftp://ftp.ensemblgenomes.org/pub/release-33/protists/gtf/dictyostelium_discoideum/Dictyostelium_discoideum.dicty_2.7.33.gtf.gz'}},
#    'ensembl_transcriptome_2.7': {'fasta': {'indexes': ['kallisto'],
#      'postprocess': 'lib.common.cat',
#      'url': ['ftp://ftp.ensemblgenomes.org/pub/protists/release-33/fasta/dictyostelium_discoideum/cdna/Dictyostelium_discoideum.dicty_2.7.cdna.all.fa.gz',
#       'ftp://ftp.ensemblgenomes.org/pub/protists/release-33/fasta/dictyostelium_discoideum/ncrna/Dictyostelium_discoideum.dicty_2.7.ncrna.fa.gz']}},
#    'rRNA': {'fasta': {'indexes': ['hisat2', 'bowtie2'],
#      'postprocess': {'args': 'Dictyostelium discoideum',
#       'function': 'lib.common.filter_fastas'},
#      'url': ['https://www.arb-silva.de/fileadmin/silva_databases/release_128/Exports/SILVA_128_LSURef_tax_silva_trunc.fasta.gz',
#       'https://www.arb-silva.de/fileadmin/silva_databases/release_128/Exports/SILVA_128_SSURef_Nr99_tax_silva_trunc.fasta.gz']}}},
#   'dmel': {'r6-16': {'fasta': {'indexes': ['bowtie2', 'hisat2'],
#      'postprocess': 'lib.postprocess.dm6.fasta_postprocess',
#      'url': 'ftp://ftp.flybase.net/genomes/Drosophila_melanogaster/dmel_r6.16_FB2017_03/fasta/dmel-all-chromosome-r6.16.fasta.gz'},
#     'gtf': {'conversions': ['refflat',
#       {'gffutils': {'disable_infer_genes': True,
#         'gtf_gene_key': 'gene_id',
#         'gtf_transcript_key': 'transcript_id',
#         'id_spec': {'gene': ['gene_id', 'gene_symbol'],
#          'transcript': ['transcript_id', 'transcript_symbol']},
#         'merge_strategy': 'merge'}},
#       {'genelist': {'gene_id': 'gene_id'}},
#       {'annotation_hub': {'ahkey': 'AH49581', 'keytype': 'ENSEMBL'}}],
#      'postprocess': 'lib.postprocess.dm6.gtf_postprocess',
#      'url': 'ftp://ftp.flybase.net/genomes/Drosophila_melanogaster/dmel_r6.16_FB2017_03/gtf/dmel-all-r6.16.gtf.gz'}},
#    'r6-16_and_ercc': {'fasta': {'indexes': ['bowtie2', 'hisat2'],
#      'postprocess': {'args': ['lib.postprocess.dm6.fasta_postprocess',
#        'lib.postprocess.ercc.fasta_postprocess'],
#       'function': 'lib.postprocess.merge.file_merge'},
#      'url': ['ftp://ftp.flybase.net/genomes/Drosophila_melanogaster/dmel_r6.16_FB2017_03/fasta/dmel-all-chromosome-r6.16.fasta.gz',
#       'https://www-s.nist.gov/srmors/certificates/documents/SRM2374_Sequence_v1.FASTA']},
#     'gtf': {'conversions': ['refflat', 'gffutils'],
#      'postprocess': {'args': ['lib.postprocess.dm6.gtf_postprocess',
#        'lib.postprocess.ercc.gtf_postprocess'],
#       'function': 'lib.postprocess.merge.file_merge'},
#      'url': ['ftp://ftp.flybase.net/genomes/Drosophila_melanogaster/dmel_r6.16_FB2017_03/gtf/dmel-all-r6.16.gtf.gz',
#       'https://www-s.nist.gov/srmors/certificates/documents/SRM2374_Sequence_v1.FASTA']}},
#    'r6-16_transcriptome': {'fasta': {'indexes': ['kallisto'],
#      'url': 'ftp://ftp.flybase.net/genomes/Drosophila_melanogaster/dmel_r6.16_FB2017_03/fasta/dmel-all-transcript-r6.16.fasta.gz'}},
#    'rRNA': {'fasta': {'indexes': ['hisat2', 'bowtie2'],
#      'postprocess': {'args': 'Drosophila melanogaster',
#       'function': 'lib.common.filter_fastas'},
#      'url': ['https://www.arb-silva.de/fileadmin/silva_databases/release_128/Exports/SILVA_128_LSURef_tax_silva_trunc.fasta.gz',
#       'https://www.arb-silva.de/fileadmin/silva_databases/release_128/Exports/SILVA_128_SSURef_Nr99_tax_silva_trunc.fasta.gz']}}},
#   'ecoli': {'default': {'fasta': {'indexes': ['bowtie2'],
#      'url': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/005/845/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.fna.gz'}}},
#   'ercc': {'fisher92': {'fasta': {'indexes': ['bowtie2', 'hisat2'],
#      'postprocess': 'lib.postprocess.erccFisher.fasta_postprocess',
#      'url': 'https://tools.thermofisher.com/content/sfs/manuals/ERCC92.zip'},
#     'gtf': {'postprocess': 'lib.postprocess.erccFisher.gtf_postprocess',
#      'url': 'https://tools.thermofisher.com/content/sfs/manuals/ERCC92.zip'}},
#    'srm2374': {'fasta': {'indexes': ['bowtie2', 'hisat2'],
#      'postprocess': 'lib.postprocess.ercc.fasta_postprocess',
#      'url': 'https://www-s.nist.gov/srmors/certificates/documents/SRM2374_Sequence_v1.FASTA'},
#     'gtf': {'postprocess': 'lib.postprocess.ercc.gtf_postprocess',
#      'url': 'https://www-s.nist.gov/srmors/certificates/documents/SRM2374_Sequence_v1.FASTA'}}},
#   'human': {'gencode-v19': {'fasta': {'indexes': ['bowtie2', 'hisat2'],
#      'url': 'ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_human/release_19/GRCh37.p13.genome.fa.gz'},
#     'gtf': {'postprocess': 'lib.postprocess.hg38.strip_ensembl_version',
#      'url': 'ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_human/release_19/gencode.v19.annotation.gtf.gz'}},
#    'gencode-v25': {'fasta': {'indexes': ['hisat2', 'bowtie2'],
#      'url': 'ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_human/release_25/GRCh38.primary_assembly.genome.fa.gz'},
#     'gtf': {'postprocess': 'lib.postprocess.hg38.strip_ensembl_version',
#      'url': 'ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_human/release_25/gencode.v25.annotation.gtf.gz'}},
#    'gencode-v25-transcriptome': {'fasta': {'indexes': ['kallisto'],
#      'url': 'ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_human/release_25/gencode.v25.transcripts.fa.gz'}},
#    'gencode_v19_plus_lncRNA_transcriptome': {'fasta': {'indexes': ['kallisto'],
#      'postprocess': 'lib.common.cat',
#      'url': ['ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_human/release_19/gencode.v19.pc_transcripts.fa.gz',
#       'ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_human/release_19/gencode.v19.lncRNA_transcripts.fa.gz']}},
#    'rRNA': {'fasta': {'indexes': ['hisat2', 'bowtie2'],
#      'postprocess': {'args': 'Homo sapiens',
#       'function': 'lib.common.filter_fastas'},
#      'url': ['https://www.arb-silva.de/fileadmin/silva_databases/release_128/Exports/SILVA_128_LSURef_tax_silva_trunc.fasta.gz',
#       'https://www.arb-silva.de/fileadmin/silva_databases/release_128/Exports/SILVA_128_SSURef_Nr99_tax_silva_trunc.fasta.gz']}}},
#   'mouse': {'gencode_m12': {'fasta': {'indexes': ['hisat2', 'bowtie2'],
#      'url': 'ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_mouse/release_M12/GRCm38.primary_assembly.genome.fa.gz'},
#     'gtf': {'conversions': ['refflat'],
#      'url': 'ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_mouse/release_M12/gencode.vM12.annotation.gtf.gz'}},
#    'gencode_m12_transcriptome': {'fasta': {'indexes': ['kallisto'],
#      'url': 'ftp://ftp.sanger.ac.uk/pub/gencode/Gencode_mouse/release_M12/gencode.vM12.transcripts.fa.gz'}}},
#   'phix': {'default': {'fasta': {'indexes': ['bowtie2'],
#      'postprocess': 'lib.postprocess.phix.fasta_postprocess',
#      'url': 'ftp://igenome:G3nom3s4u@ussd-ftp.illumina.com/PhiX/Illumina/RTA/PhiX_Illumina_RTA.tar.gz'}}},
#   'sacCer3': {'default': {'fasta': {'indexes': ['bowtie2'],
#      'postprocess': 'lib.postprocess.sacCer3.fasta_postprocess',
#      'url': 'http://hgdownload.cse.ucsc.edu/goldenPath/sacCer3/bigZips/chromFa.tar.gz'}}},
#   'wolbachia': {'default': {'fasta': {'indexes': ['bowtie2'],
#      'url': 'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/008/025/GCF_000008025.1_ASM802v1/GCF_000008025.1_ASM802v1_genomic.fna.gz'}}}},
#  'rrna': {'index': 'bowtie2', 'tag': 'rRNA'},
#  'sample_dir': 'data/rnaseq_samples',
#  'sampletable': 'config/sampletable.tsv'}
